# %% [markdown]
# <font size='6'><b>E-commerce analytics</b></font><br><br>
# <font size='4'>Antonio Buzzelli</font><br>
# <font size='4'>March 2023</font>
#
# Dataset: https://www.kaggle.com/datasets/gabrielramos87/an-online-shop-business?sort=published

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %%
df = pd.read_csv('sales.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536350 entries, 0 to 536349
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  536350 non-null  object
#  1   Date           536350 non-null  object
#  2   ProductNo      536350 non-null  object
#  3   ProductName    536350 non-null  object
#  4   Price          536350 non-null  float64
#  5   Quantity       536350 non-null  int64
#  6   CustomerNo     536295 non-null  float64
#  7   Country        536350 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.7+ MB

# %%
df
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...                                     ...    ...       ...         ...
# 536345         Organiser Wood Antique White  18.96        -2     12472.0
# 536346               Red Spotty Biscuit Tin  14.09        -3     12472.0
# 536347         Porcelain Hanging Bell Small  11.74        -1     12472.0
# 536348         Advent Calendar Gingham Sack  16.35        -4     12472.0
# 536349           Triple Photo Frame Cornice  20.45        -2     12472.0
#
#                Country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# 4       United Kingdom
# ...                ...
# 536345         Germany
# 536346         Germany
# 536347         Germany
# 536348         Germany
# 536349         Germany
#
# [536350 rows x 8 columns]

# %% [markdown]
# * TransactionNo (categorical): a six-digit unique number that defines each transaction. The letter “C” in the code indicates a cancellation.
# * Date (numeric): the date when each transaction was generated.
# * ProductNo (categorical): a five or six-digit unique character used to identify a specific product.
# * Product (categorical): product/item name.
# * Price (numeric): the price of each product per unit in pound sterling (£).
# * Quantity (numeric): the quantity of each product per transaction. Negative values related to cancelled transactions.
# * CustomerNo (categorical): a five-digit unique number that defines each customer.
# * Country (categorical): name of the country where the customer resides.

# %%
df['Date'] = pd.to_datetime(df['Date'])
df[['ProductNo', 'CustomerNo']] = df[['ProductNo', 'CustomerNo']].astype('object')
# Creating a `TotalPrice` colum
df['TotalPrice'] = df['Quantity'] * df['Price']
# Creating another `TotalPrice` column that takes into consideration returns (represented by -n values in the `Quantity` column).
df['TotalPriceN'] = np.where(df['TotalPrice'] < 0, 0, df['TotalPrice'])

# %%
df
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482 2019-12-09     22485
# 1             581475 2019-12-09     22596
# 2             581475 2019-12-09     23235
# 3             581475 2019-12-09     23272
# 4             581475 2019-12-09     23239
# ...              ...        ...       ...
# 536345       C536548 2018-12-01     22168
# 536346       C536548 2018-12-01     21218
# 536347       C536548 2018-12-01     20957
# 536348       C536548 2018-12-01     22580
# 536349       C536548 2018-12-01     22767
#
#                                 ProductName  Price  Quantity CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12    17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36    13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12    13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12    13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6    13069.0
# ...                                     ...    ...       ...        ...
# 536345         Organiser Wood Antique White  18.96        -2    12472.0
# 536346               Red Spotty Biscuit Tin  14.09        -3    12472.0
# 536347         Porcelain Hanging Bell Small  11.74        -1    12472.0
# 536348         Advent Calendar Gingham Sack  16.35        -4    12472.0
# 536349           Triple Photo Frame Cornice  20.45        -2    12472.0
#
#                Country  TotalPrice  TotalPriceN
# 0       United Kingdom      257.64       257.64
# 1       United Kingdom      383.40       383.40
# 2       United Kingdom      138.36       138.36
# 3       United Kingdom      127.80       127.80
# 4       United Kingdom       71.64        71.64
# ...                ...         ...          ...
# 536345         Germany      -37.92         0.00
# 536346         Germany      -42.27         0.00
# 536347         Germany      -11.74         0.00
# 536348         Germany      -65.40         0.00
# 536349         Germany      -40.90         0.00
#
# [536350 rows x 10 columns]

# %% [markdown]
# ## Missing values

# %%
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# CustomerNo       0.000103
# TransactionNo    0.000000
# Date             0.000000
# ProductNo        0.000000
# ProductName      0.000000
# Price            0.000000
# Quantity         0.000000
# Country          0.000000
# TotalPrice       0.000000
# TotalPriceN      0.000000
# dtype: float64

# %% [markdown]
# Fortunately, the dataset presents only a negligeable amount of null values (in the `CustomerNo` column). We can afford to drop 55 observations.

# %%
df = df.dropna(subset=['CustomerNo'])

# %% [markdown]
# # Exploratory analysis

# %% [markdown]
# ## Categorical variables

# %%
df.select_dtypes('object')
# Out:
#        TransactionNo ProductNo                          ProductName  \
# 0             581482     22485        Set Of 2 Wooden Market Crates
# 1             581475     22596  Christmas Star Wish List Chalkboard
# 2             581475     23235             Storage Tin Vintage Leaf
# 3             581475     23272    Tree T-Light Holder Willie Winkie
# 4             581475     23239    Set Of 4 Knick Knack Tins Poppies
# ...              ...       ...                                  ...
# 536345       C536548     22168         Organiser Wood Antique White
# 536346       C536548     21218               Red Spotty Biscuit Tin
# 536347       C536548     20957         Porcelain Hanging Bell Small
# 536348       C536548     22580         Advent Calendar Gingham Sack
# 536349       C536548     22767           Triple Photo Frame Cornice
#
#        CustomerNo         Country
# 0         17490.0  United Kingdom
# 1         13069.0  United Kingdom
# 2         13069.0  United Kingdom
# 3         13069.0  United Kingdom
# 4         13069.0  United Kingdom
# ...           ...             ...
# 536345    12472.0         Germany
# 536346    12472.0         Germany
# 536347    12472.0         Germany
# 536348    12472.0         Germany
# 536349    12472.0         Germany
#
# [536295 rows x 5 columns]

# %% [markdown]
# ## Numeric variables

# %%
logs = np.log(df.select_dtypes([int, float]))
logs.columns = ['log'+c for c in logs.columns]
# Out:
# /usr/lib64/python3.11/site-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /usr/lib64/python3.11/site-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)

# %%
sns.boxplot(x=logs['logTotalPrice'])
# Out:
# <AxesSubplot: xlabel='logTotalPrice'>

# %%
sns.regplot(logs, x='logQuantity', y='logTotalPrice')
# Out:
# <AxesSubplot: xlabel='logQuantity', ylabel='logTotalPrice'>
